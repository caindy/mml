# %%
import pandas as pd
# obtain the all_regional_mtlf_after_intg.parquet file from 
# https://www.kaggle.com/dataset/fa253a48766d3621ee0cd56fa478ed464af7672d22b10cf7e9f294da728063b0
file_name = 'all_regional_mtlf_after_intg.parquet'
df = pd.read_parquet(f'../data/{file_name}')

# %%
df.head()
# Out:
#       Market Day  HourEnding  Central MTLF (MWh)  Central ActualLoad (MWh)  \
# index
# 1     2013-12-19           1               41751                  39858.94
# 2     2013-12-19           2               39836                  38594.68
# 3     2013-12-19           3               39093                  37839.24
# 4     2013-12-19           4               38790                  37481.78
# 5     2013-12-19           5               39074                  37602.45
#
#        North MTLF (MWh)  North ActualLoad (MWh)  South MTLF (MWh)  \
# index
# 1                 16495                16611.45             16938
# 2                 15856                16066.07             16423
# 3                 15447                15740.73             16202
# 4                 15295                15554.97             16195
# 5                 15314                15575.60             16356
#
#        South ActualLoad (MWh)  MISO MTLF (MWh)  MISO ActualLoad (MWh)
# index
# 1                    16954.60            75184               73424.99
# 2                    17244.03            72115               71904.78
# 3                    16718.23            70742               70298.20
# 4                    16607.76            70280               69644.51
# 5                    16479.79            70744               69657.84
